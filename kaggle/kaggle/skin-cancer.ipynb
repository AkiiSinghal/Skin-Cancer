# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image
np.random.seed(11) # It's my lucky number
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score
import itertools
import keras
from keras.utils.np_utils import to_categorical # used for converting labels to one-hot-encoding
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras import backend as K
from keras.layers.normalization import BatchNormalization
from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from keras.optimizers import Adam, RMSprop
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from keras.wrappers.scikit_learn import KerasClassifier
from keras.applications.resnet50 import ResNet50
from keras import backend as K

# %%
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
folder_benign_train = '../input/skincancer/input/data/train/benign'
folder_malignant_train = '../input/skincancer/input/data/train/malignant'

folder_benign_test = '../input/skincancer/input/data/test/benign'
folder_malignant_test = '../input/skincancer/input/data/test/malignant'

read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))

# Load in training pictures 
ims_benign = [read(os.path.join(folder_benign_train, filename)) for filename in os.listdir(folder_benign_train)]
X_benign = np.array(ims_benign, dtype='uint8')
ims_malignant = [read(os.path.join(folder_malignant_train, filename)) for filename in os.listdir(folder_malignant_train)]
X_malignant = np.array(ims_malignant, dtype='uint8')

# Load in testing pictures
ims_benign = [read(os.path.join(folder_benign_test, filename)) for filename in os.listdir(folder_benign_test)]
X_benign_test = np.array(ims_benign, dtype='uint8')
ims_malignant = [read(os.path.join(folder_malignant_test, filename)) for filename in os.listdir(folder_malignant_test)]
X_malignant_test = np.array(ims_malignant, dtype='uint8')

# Create labels
y_benign = np.zeros(X_benign.shape[0])
y_malignant = np.ones(X_malignant.shape[0])

y_benign_test = np.zeros(X_benign_test.shape[0])
y_malignant_test = np.ones(X_malignant_test.shape[0])


# Merge data 
X_train = np.concatenate((X_benign, X_malignant), axis = 0)
y_train = np.concatenate((y_benign, y_malignant), axis = 0)

X_test = np.concatenate((X_benign_test, X_malignant_test), axis = 0)
y_test = np.concatenate((y_benign_test, y_malignant_test), axis = 0)

# Shuffle data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
y_train = y_train[s]

s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
y_test = y_test[s]

# %%
# Display first 15 images of moles, and how they are classified
w=40
h=30
fig=plt.figure(figsize=(12, 8))
columns = 5
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if y_train[i] == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(X_train[i], interpolation='nearest')
plt.show()

# %%
#Categorical Labels

y_train = to_categorical(y_train, num_classes= 2)
y_test = to_categorical(y_test, num_classes= 2)

# %%
#Normalization
#Normalize all Values of the pictures by dividing all the RGB values by 255

# With data augmentation to prevent overfitting 
X_train = X_train/255.
X_test = X_test/255.

# %%
# Model Building
# See learning curve and validation curve

def build(input_shape= (224,224,3), lr = 1e-3, num_classes= 2, init= 'normal', activ= 'relu', optim= 'adam'):
    model = Sequential()
    model.add(Conv2D(64, kernel_size=(3, 3),padding = 'Same',input_shape=input_shape, activation= activ, kernel_initializer='glorot_uniform'))
    model.add(MaxPool2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, kernel_size=(3, 3),padding = 'Same', activation =activ, kernel_initializer = 'glorot_uniform'))
    model.add(MaxPool2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer=init))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()

    if optim == 'rmsprop':
        optimizer = RMSprop(lr=lr)

    else:
        optimizer = Adam(lr=lr)

    model.compile(optimizer = optimizer ,loss = "binary_crossentropy", metrics=["accuracy"])
    return model

# Set a learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=5, verbose=1, factor=0.5, min_lr=1e-7)

# %%
input_shape = (224,224,3)
lr = 1e-5
init = 'normal'
activ = 'relu'
optim = 'adam'
epochs = 50
batch_size = 64

# %%
model = build(lr=lr, init= init, activ= activ, optim=optim, input_shape= input_shape)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 56, 56, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 200704)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               25690240
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 25,729,218
# Trainable params: 25,729,218
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, validation_split=0.2, epochs= epochs, batch_size= batch_size, verbose=1, callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/50
# 33/33 [==============================] - 23s 505ms/step - loss: 1.6290 - accuracy: 0.5037 - val_loss: 0.7183 - val_accuracy: 0.5379
# Epoch 2/50
# 33/33 [==============================] - 13s 404ms/step - loss: 1.0261 - accuracy: 0.5375 - val_loss: 0.7473 - val_accuracy: 0.5360
# Epoch 3/50
# 33/33 [==============================] - 13s 402ms/step - loss: 0.9701 - accuracy: 0.5319 - val_loss: 0.7558 - val_accuracy: 0.5360
# Epoch 4/50
# 33/33 [==============================] - 13s 403ms/step - loss: 0.8864 - accuracy: 0.5598 - val_loss: 0.7423 - val_accuracy: 0.5360
# Epoch 5/50
# 33/33 [==============================] - 13s 404ms/step - loss: 0.8462 - accuracy: 0.5508 - val_loss: 0.7395 - val_accuracy: 0.5360
# Epoch 6/50
# 33/33 [==============================] - 13s 404ms/step - loss: 0.8023 - accuracy: 0.5750 - val_loss: 0.7233 - val_accuracy: 0.5360
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# Epoch 7/50
# 33/33 [==============================] - 13s 402ms/step - loss: 0.7572 - accuracy: 0.5800 - val_loss: 0.7322 - val_accuracy: 0.5360
# Epoch 8/50
# 33/33 [==============================] - 13s 402ms/step - loss: 0.7436 - accuracy: 0.5946 - val_loss: 0.7179 - val_accuracy: 0.5360
# Epoch 9/50
# 33/33 [==============================] - 13s 405ms/step - loss: 0.7207 - accuracy: 0.6007 - val_loss: 0.7142 - val_accuracy: 0.5360
# Epoch 10/50
# 33/33 [==============================] - 13s 403ms/step - loss: 0.7061 - accuracy: 0.6206 - val_loss: 0.7398 - val_accuracy: 0.5360
# Epoch 11/50
# 33/33 [==============================] - 13s 403ms/step - loss: 0.7192 - accuracy: 0.5931 - val_loss: 0.7169 - val_accuracy: 0.5360
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# Epoch 12/50
# 33/33 [==============================] - 13s 404ms/step - loss: 0.6804 - accuracy: 0.6272 - val_loss: 0.7125 - val_accuracy: 0.5360
# Epoch 13/50
# 33/33 [==============================] - 13s 403ms/step - loss: 0.6751 - accuracy: 0.6191 - val_loss: 0.7137 - val_accuracy: 0.5360
# Epoch 14/50
# 33/33 [==============================] - 13s 404ms/step - loss: 0.6814 - accuracy: 0.6234 - val_loss: 0.7128 - val_accuracy: 0.5360
# Epoch 15/50
# 33/33 [==============================] - 13s 405ms/step - loss: 0.6886 - accuracy: 0.6369 - val_loss: 0.7157 - val_accuracy: 0.5360
# Epoch 16/50
# 33/33 [==============================] - 13s 402ms/step - loss: 0.6838 - accuracy: 0.6171 - val_loss: 0.7105 - val_accuracy: 0.5360
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# Epoch 17/50
# 33/33 [==============================] - 13s 400ms/step - loss: 0.6775 - accuracy: 0.6182 - val_loss: 0.7062 - val_accuracy: 0.5360
# Epoch 18/50
# 33/33 [==============================] - 13s 402ms/step - loss: 0.6676 - accuracy: 0.6452 - val_loss: 0.7067 - val_accuracy: 0.5360
# Epoch 19/50
# 33/33 [==============================] - 13s 405ms/step - loss: 0.6713 - accuracy: 0.6215 - val_loss: 0.7073 - val_accuracy: 0.5360
# Epoch 20/50
# 33/33 [==============================] - 13s 404ms/step - loss: 0.6695 - accuracy: 0.6177 - val_loss: 0.7035 - val_accuracy: 0.5360
# Epoch 21/50
# 33/33 [==============================] - 13s 403ms/step - loss: 0.6685 - accuracy: 0.6426 - val_loss: 0.7037 - val_accuracy: 0.5360
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
# Epoch 22/50
# 33/33 [==============================] - 13s 404ms/step - loss: 0.6975 - accuracy: 0.6032 - val_loss: 0.7024 - val_accuracy: 0.5360
# Epoch 23/50
# 33/33 [==============================] - 13s 401ms/step - loss: 0.6703 - accuracy: 0.6256 - val_loss: 0.7035 - val_accuracy: 0.5360
# Epoch 24/50
# 33/33 [==============================] - 13s 405ms/step - loss: 0.6498 - accuracy: 0.6184 - val_loss: 0.7032 - val_accuracy: 0.5360
# Epoch 25/50
# 33/33 [==============================] - 13s 403ms/step - loss: 0.6560 - accuracy: 0.6412 - val_loss: 0.7057 - val_accuracy: 0.5360
# Epoch 26/50
# 33/33 [==============================] - 13s 402ms/step - loss: 0.6672 - accuracy: 0.6308 - val_loss: 0.7084 - val_accuracy: 0.5360
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
# Epoch 27/50
# 33/33 [==============================] - 13s 401ms/step - loss: 0.6613 - accuracy: 0.6334 - val_loss: 0.7070 - val_accuracy: 0.5360
# Epoch 28/50
# 33/33 [==============================] - 13s 403ms/step - loss: 0.6573 - accuracy: 0.6517 - val_loss: 0.7040 - val_accuracy: 0.5360
# Epoch 29/50
# 33/33 [==============================] - 13s 405ms/step - loss: 0.6828 - accuracy: 0.6013 - val_loss: 0.7035 - val_accuracy: 0.5360
# Epoch 30/50
# 33/33 [==============================] - 13s 404ms/step - loss: 0.6651 - accuracy: 0.6301 - val_loss: 0.7040 - val_accuracy: 0.5360
# Epoch 31/50
# 33/33 [==============================] - 13s 406ms/step - loss: 0.6737 - accuracy: 0.6216 - val_loss: 0.7048 - val_accuracy: 0.5360
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
# Epoch 32/50
# 33/33 [==============================] - 13s 401ms/step - loss: 0.6641 - accuracy: 0.6259 - val_loss: 0.7046 - val_accuracy: 0.5360
# Epoch 33/50
# 33/33 [==============================] - 13s 402ms/step - loss: 0.6692 - accuracy: 0.6337 - val_loss: 0.7029 - val_accuracy: 0.5360
# Epoch 34/50
# 33/33 [==============================] - 13s 405ms/step - loss: 0.6547 - accuracy: 0.6446 - val_loss: 0.7023 - val_accuracy: 0.5360
# Epoch 35/50
# 33/33 [==============================] - 13s 400ms/step - loss: 0.6767 - accuracy: 0.6283 - val_loss: 0.7031 - val_accuracy: 0.5360
# Epoch 36/50
# 33/33 [==============================] - 13s 404ms/step - loss: 0.6622 - accuracy: 0.6356 - val_loss: 0.7027 - val_accuracy: 0.5360
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 37/50
# 33/33 [==============================] - 13s 401ms/step - loss: 0.6639 - accuracy: 0.6312 - val_loss: 0.7026 - val_accuracy: 0.5360
# Epoch 38/50
# 33/33 [==============================] - 13s 403ms/step - loss: 0.6741 - accuracy: 0.6357 - val_loss: 0.7026 - val_accuracy: 0.5360
# Epoch 39/50
# 33/33 [==============================] - 13s 402ms/step - loss: 0.6480 - accuracy: 0.6395 - val_loss: 0.7023 - val_accuracy: 0.5360
# Epoch 40/50
# 33/33 [==============================] - 13s 402ms/step - loss: 0.6710 - accuracy: 0.6163 - val_loss: 0.7019 - val_accuracy: 0.5360
# Epoch 41/50
# 33/33 [==============================] - 13s 403ms/step - loss: 0.6666 - accuracy: 0.6134 - val_loss: 0.7013 - val_accuracy: 0.5360
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 42/50
# 33/33 [==============================] - 13s 403ms/step - loss: 0.6677 - accuracy: 0.6295 - val_loss: 0.7007 - val_accuracy: 0.5360
# Epoch 43/50
# 33/33 [==============================] - 13s 402ms/step - loss: 0.6536 - accuracy: 0.6457 - val_loss: 0.7008 - val_accuracy: 0.5360
# Epoch 44/50
# 33/33 [==============================] - 13s 404ms/step - loss: 0.6588 - accuracy: 0.6550 - val_loss: 0.7000 - val_accuracy: 0.5360
# Epoch 45/50
# 33/33 [==============================] - 13s 401ms/step - loss: 0.6768 - accuracy: 0.6188 - val_loss: 0.7004 - val_accuracy: 0.5360
# Epoch 46/50
# 33/33 [==============================] - 13s 402ms/step - loss: 0.6590 - accuracy: 0.6387 - val_loss: 0.7001 - val_accuracy: 0.5360
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 47/50
# 33/33 [==============================] - 13s 400ms/step - loss: 0.6666 - accuracy: 0.6309 - val_loss: 0.7003 - val_accuracy: 0.5360
# Epoch 48/50
# 33/33 [==============================] - 13s 403ms/step - loss: 0.6538 - accuracy: 0.6213 - val_loss: 0.7006 - val_accuracy: 0.5360
# Epoch 49/50
# 33/33 [==============================] - 13s 405ms/step - loss: 0.6626 - accuracy: 0.6274 - val_loss: 0.7008 - val_accuracy: 0.5360
# Epoch 50/50
# 33/33 [==============================] - 13s 401ms/step - loss: 0.6706 - accuracy: 0.6285 - val_loss: 0.7010 - val_accuracy: 0.5360

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
K.clear_session()
del model
del history

# %%
#Cross-Validating Model

# define 3-fold cross validation test harness
kfold = KFold(n_splits=3, shuffle=True, random_state=11)

cvscores = []
for train, test in kfold.split(X_train, y_train):
    # create model
    model = build(lr=lr, 
                  init= init, 
                  activ= activ, 
                  optim=optim, 
                  input_shape= input_shape)
    
    # Fit the model
    model.fit(X_train[train], y_train[train], epochs=epochs, batch_size=batch_size, verbose=1)
    # evaluate the model
    scores = model.evaluate(X_train[test], y_train[test], verbose=1)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
    K.clear_session()
    del model
    
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 56, 56, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 200704)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               25690240
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 25,729,218
# Trainable params: 25,729,218
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 28/28 [==============================] - 11s 361ms/step - loss: 1.7088 - accuracy: 0.4730
# Epoch 2/50
# 28/28 [==============================] - 9s 324ms/step - loss: 1.0968 - accuracy: 0.4936
# Epoch 3/50
# 28/28 [==============================] - 9s 320ms/step - loss: 0.9498 - accuracy: 0.5427
# Epoch 4/50
# 28/28 [==============================] - 9s 328ms/step - loss: 0.9002 - accuracy: 0.5558
# Epoch 5/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.8627 - accuracy: 0.5930
# Epoch 6/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.8634 - accuracy: 0.5733
# Epoch 7/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.7515 - accuracy: 0.6210
# Epoch 8/50
# 28/28 [==============================] - 9s 325ms/step - loss: 0.7511 - accuracy: 0.6223
# Epoch 9/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.7034 - accuracy: 0.6439
# Epoch 10/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.6763 - accuracy: 0.6546
# Epoch 11/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.6398 - accuracy: 0.6791
# Epoch 12/50
# 28/28 [==============================] - 9s 325ms/step - loss: 0.6683 - accuracy: 0.6355
# Epoch 13/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.6730 - accuracy: 0.6484
# Epoch 14/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.6080 - accuracy: 0.6975
# Epoch 15/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.6001 - accuracy: 0.7037
# Epoch 16/50
# 28/28 [==============================] - 9s 319ms/step - loss: 0.5985 - accuracy: 0.7002
# Epoch 17/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.6086 - accuracy: 0.6953
# Epoch 18/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.6034 - accuracy: 0.6948
# Epoch 19/50
# 28/28 [==============================] - 9s 325ms/step - loss: 0.5747 - accuracy: 0.7040
# Epoch 20/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.5782 - accuracy: 0.7124
# Epoch 21/50
# 28/28 [==============================] - 9s 325ms/step - loss: 0.5543 - accuracy: 0.7304
# Epoch 22/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.5492 - accuracy: 0.7329
# Epoch 23/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.5691 - accuracy: 0.7235
# Epoch 24/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.5424 - accuracy: 0.7256
# Epoch 25/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.5273 - accuracy: 0.7397
# Epoch 26/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.5353 - accuracy: 0.7157
# Epoch 27/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.5467 - accuracy: 0.7260
# Epoch 28/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.5159 - accuracy: 0.7549
# Epoch 29/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.5261 - accuracy: 0.7494
# Epoch 30/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.5460 - accuracy: 0.7083
# Epoch 31/50
# 28/28 [==============================] - 9s 328ms/step - loss: 0.5009 - accuracy: 0.7519
# Epoch 32/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.4959 - accuracy: 0.7487
# Epoch 33/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.5027 - accuracy: 0.7661
# Epoch 34/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.4847 - accuracy: 0.7526
# Epoch 35/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.5163 - accuracy: 0.7432
# Epoch 36/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.4973 - accuracy: 0.7522
# Epoch 37/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.5109 - accuracy: 0.7336
# Epoch 38/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.4788 - accuracy: 0.7609
# Epoch 39/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.4935 - accuracy: 0.7443
# Epoch 40/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.4795 - accuracy: 0.7646
# Epoch 41/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.4816 - accuracy: 0.7534
# Epoch 42/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.4862 - accuracy: 0.7451
# Epoch 43/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.4652 - accuracy: 0.7719
# Epoch 44/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.4895 - accuracy: 0.7502
# Epoch 45/50
# 28/28 [==============================] - 9s 327ms/step - loss: 0.4681 - accuracy: 0.7695
# Epoch 46/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.4625 - accuracy: 0.7680
# Epoch 47/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.4916 - accuracy: 0.7487
# Epoch 48/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.4662 - accuracy: 0.7616
# Epoch 49/50
# 28/28 [==============================] - 9s 326ms/step - loss: 0.4510 - accuracy: 0.7770
# Epoch 50/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.4661 - accuracy: 0.7683
# 28/28 [==============================] - 5s 152ms/step - loss: 0.5452 - accuracy: 0.6769
# accuracy: 67.69%
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 56, 56, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 200704)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               25690240
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 25,729,218
# Trainable params: 25,729,218
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 28/28 [==============================] - 10s 321ms/step - loss: 1.0844 - accuracy: 0.5190
# Epoch 2/50
# 28/28 [==============================] - 9s 320ms/step - loss: 0.8884 - accuracy: 0.5613
# Epoch 3/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.8686 - accuracy: 0.5468
# Epoch 4/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.7882 - accuracy: 0.5964
# Epoch 5/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.7338 - accuracy: 0.6083
# Epoch 6/50
# 28/28 [==============================] - 9s 320ms/step - loss: 0.7224 - accuracy: 0.6306
# Epoch 7/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.7049 - accuracy: 0.6319
# Epoch 8/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.6867 - accuracy: 0.6450
# Epoch 9/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.6512 - accuracy: 0.6813
# Epoch 10/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.6426 - accuracy: 0.6616
# Epoch 11/50
# 28/28 [==============================] - 9s 320ms/step - loss: 0.6035 - accuracy: 0.7081
# Epoch 12/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.5989 - accuracy: 0.7120
# Epoch 13/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.6113 - accuracy: 0.6787
# Epoch 14/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.6181 - accuracy: 0.6638
# Epoch 15/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.5748 - accuracy: 0.7156
# Epoch 16/50
# 28/28 [==============================] - 9s 325ms/step - loss: 0.5808 - accuracy: 0.7024
# Epoch 17/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.5662 - accuracy: 0.7148
# Epoch 18/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.5524 - accuracy: 0.7356
# Epoch 19/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.5982 - accuracy: 0.6920
# Epoch 20/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.5582 - accuracy: 0.6987
# Epoch 21/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.5715 - accuracy: 0.6985
# Epoch 22/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.5429 - accuracy: 0.7368
# Epoch 23/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.5697 - accuracy: 0.7008
# Epoch 24/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.5407 - accuracy: 0.7235
# Epoch 25/50
# 28/28 [==============================] - 9s 320ms/step - loss: 0.5295 - accuracy: 0.7313
# Epoch 26/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.5116 - accuracy: 0.7480
# Epoch 27/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.5197 - accuracy: 0.7410
# Epoch 28/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.5330 - accuracy: 0.7184
# Epoch 29/50
# 28/28 [==============================] - 9s 320ms/step - loss: 0.5281 - accuracy: 0.7171
# Epoch 30/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.5162 - accuracy: 0.7294
# Epoch 31/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.5144 - accuracy: 0.7309
# Epoch 32/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.5100 - accuracy: 0.7425
# Epoch 33/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.5103 - accuracy: 0.7415
# Epoch 34/50
# 28/28 [==============================] - 9s 326ms/step - loss: 0.5087 - accuracy: 0.7391
# Epoch 35/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.4958 - accuracy: 0.7511
# Epoch 36/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.5038 - accuracy: 0.7382
# Epoch 37/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.5098 - accuracy: 0.7404
# Epoch 38/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.5190 - accuracy: 0.7315
# Epoch 39/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.5158 - accuracy: 0.7364
# Epoch 40/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.5222 - accuracy: 0.7319
# Epoch 41/50
# 28/28 [==============================] - 9s 325ms/step - loss: 0.4900 - accuracy: 0.7482
# Epoch 42/50
# 28/28 [==============================] - 9s 326ms/step - loss: 0.4758 - accuracy: 0.7626
# Epoch 43/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.4782 - accuracy: 0.7542
# Epoch 44/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.4975 - accuracy: 0.7440
# Epoch 45/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.4846 - accuracy: 0.7430
# Epoch 46/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.4677 - accuracy: 0.7649
# Epoch 47/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.4812 - accuracy: 0.7514
# Epoch 48/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.4881 - accuracy: 0.7324
# Epoch 49/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.4741 - accuracy: 0.7472
# Epoch 50/50
# 28/28 [==============================] - 9s 325ms/step - loss: 0.4727 - accuracy: 0.7498
# 28/28 [==============================] - 4s 137ms/step - loss: 0.6133 - accuracy: 0.5927
# accuracy: 59.27%
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 56, 56, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 200704)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               25690240
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 25,729,218
# Trainable params: 25,729,218
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting model to all data
model = build(lr=lr, init= init, activ= activ, optim=optim, input_shape= input_shape)

model.fit(X_train, y_train, epochs=epochs, batch_size= batch_size, verbose=1, callbacks=[learning_rate_reduction])

# Testing model on test data to evaluate
y_pred = model.predict_classes(X_test)

print(accuracy_score(np.argmax(y_test, axis=1),y_pred))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 56, 56, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 200704)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               25690240
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 25,729,218
# Trainable params: 25,729,218
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 42/42 [==============================] - 21s 335ms/step - loss: 1.2434 - accuracy: 0.4886
# Epoch 2/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.9130 - accuracy: 0.5458
# Epoch 3/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.8486 - accuracy: 0.5692
# Epoch 4/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.7920 - accuracy: 0.5940
# Epoch 5/50
# 42/42 [==============================] - 14s 322ms/step - loss: 0.7514 - accuracy: 0.6037
# Epoch 6/50
# 42/42 [==============================] - 14s 324ms/step - loss: 0.6931 - accuracy: 0.6180
# Epoch 7/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.6913 - accuracy: 0.6228
# Epoch 8/50
# 42/42 [==============================] - 14s 325ms/step - loss: 0.6405 - accuracy: 0.6561
# Epoch 9/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.6351 - accuracy: 0.6506
# Epoch 10/50
# 42/42 [==============================] - 14s 324ms/step - loss: 0.6160 - accuracy: 0.6707
# Epoch 11/50
# 42/42 [==============================] - 14s 322ms/step - loss: 0.6126 - accuracy: 0.6651
# Epoch 12/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.6200 - accuracy: 0.6654
# Epoch 13/50
# 42/42 [==============================] - 14s 326ms/step - loss: 0.5957 - accuracy: 0.6923
# Epoch 14/50
# 42/42 [==============================] - 14s 322ms/step - loss: 0.5792 - accuracy: 0.6915
# Epoch 15/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.5765 - accuracy: 0.6950
# Epoch 16/50
# 42/42 [==============================] - 14s 324ms/step - loss: 0.5622 - accuracy: 0.7109
# Epoch 17/50
# 42/42 [==============================] - 14s 324ms/step - loss: 0.5528 - accuracy: 0.7197
# Epoch 18/50
# 42/42 [==============================] - 14s 324ms/step - loss: 0.5498 - accuracy: 0.7168
# Epoch 19/50
# 42/42 [==============================] - 14s 324ms/step - loss: 0.5496 - accuracy: 0.7119
# Epoch 20/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.5330 - accuracy: 0.7326
# Epoch 21/50
# 42/42 [==============================] - 14s 325ms/step - loss: 0.5245 - accuracy: 0.7401
# Epoch 22/50
# 42/42 [==============================] - 14s 324ms/step - loss: 0.5311 - accuracy: 0.7323
# Epoch 23/50
# 42/42 [==============================] - 14s 325ms/step - loss: 0.5237 - accuracy: 0.7371
# Epoch 24/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.5151 - accuracy: 0.7492
# Epoch 25/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.5149 - accuracy: 0.7414
# Epoch 26/50
# 42/42 [==============================] - 14s 326ms/step - loss: 0.5057 - accuracy: 0.7422
# Epoch 27/50
# 42/42 [==============================] - 14s 322ms/step - loss: 0.5220 - accuracy: 0.7395
# Epoch 28/50
# 42/42 [==============================] - 14s 324ms/step - loss: 0.4939 - accuracy: 0.7558
# Epoch 29/50
# 42/42 [==============================] - 14s 325ms/step - loss: 0.5148 - accuracy: 0.7322
# Epoch 30/50
# 42/42 [==============================] - 14s 326ms/step - loss: 0.4988 - accuracy: 0.7477
# Epoch 31/50
# 42/42 [==============================] - 14s 322ms/step - loss: 0.4846 - accuracy: 0.7600
# Epoch 32/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.4862 - accuracy: 0.7646
# Epoch 33/50
# 42/42 [==============================] - 14s 324ms/step - loss: 0.4891 - accuracy: 0.7603
# Epoch 34/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.4824 - accuracy: 0.7480
# Epoch 35/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.4935 - accuracy: 0.7501
# Epoch 36/50
# 42/42 [==============================] - 14s 324ms/step - loss: 0.4802 - accuracy: 0.7624
# Epoch 37/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.4762 - accuracy: 0.7688
# Epoch 38/50
# 42/42 [==============================] - 14s 325ms/step - loss: 0.5019 - accuracy: 0.7583
# Epoch 39/50
# 42/42 [==============================] - 14s 325ms/step - loss: 0.4849 - accuracy: 0.7663
# Epoch 40/50
# 42/42 [==============================] - 14s 326ms/step - loss: 0.4742 - accuracy: 0.7631
# Epoch 41/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.4682 - accuracy: 0.7586
# Epoch 42/50
# 42/42 [==============================] - 14s 325ms/step - loss: 0.4751 - accuracy: 0.7591
# Epoch 43/50
# 42/42 [==============================] - 14s 325ms/step - loss: 0.4708 - accuracy: 0.7692
# Epoch 44/50
# 42/42 [==============================] - 14s 324ms/step - loss: 0.4881 - accuracy: 0.7504
# Epoch 45/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.4537 - accuracy: 0.7825
# Epoch 46/50
# 42/42 [==============================] - 14s 324ms/step - loss: 0.4524 - accuracy: 0.7837
# Epoch 47/50
# 42/42 [==============================] - 14s 324ms/step - loss: 0.4696 - accuracy: 0.7550
# Epoch 48/50
# 42/42 [==============================] - 14s 322ms/step - loss: 0.4598 - accuracy: 0.7773
# Epoch 49/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.4551 - accuracy: 0.7879
# Epoch 50/50
# 42/42 [==============================] - 14s 323ms/step - loss: 0.4594 - accuracy: 0.7837
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 0.7606060606060606

# %%
# Testing model on test data to evaluate
y_pred = np.argmax(model.predict(X_test), axis=-1)#(model.predict(X_test) > 0.5).astype("int32")

print(accuracy_score(np.argmax(y_test, axis=1),y_pred))
# Out:
# 0.7636363636363637

# %%
# save model
# serialize model to JSON
model_json = model.to_json()

with open("model.json", "w") as json_file:
    json_file.write(model_json)
    
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")

# Clear memory, because of memory overload
del model
K.clear_session()
# Out:
# Saved model to disk
